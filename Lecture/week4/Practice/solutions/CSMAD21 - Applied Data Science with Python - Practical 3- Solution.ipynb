# %% [markdown]
# # CSMAD21 - Applied Data Science with Python - Practical 3
#
# ## Pandas
#
# Follow the instructions to complete each of these tasks. This set of exercises focuses on working with Python's Pandas library.
#
# The relevant materials for these exercises is lectures 5 and 6 (Pandas).
#
# This is not assessed but will help you gain practical experience for the exam and coursework.
#
# You will need to download some of the csv data set files from the module Blackboard page and place them in the same folder as this notebook. Run the cell below to load all of the necessary Python modules.
#
# **Questions marked with a * are extra challenging**

# %%
import pandas as pd
import requests
import numpy as np
from pandas import json_normalize

# %% [markdown]
# ## 1. Diamonds example data
#
# 1.1. Read in the diamonds csv file to a pandas data frame. Use pandas to find how many diamonds have carat greater than 3.5.

# %%
diamonds = pd.read_csv('Datasets/diamonds.csv')
diamonds.loc[diamonds['carat']> 3.5]
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 23644   3.65       Fair     H      I1   67.1   53.0  11668   9.53   9.48  6.38
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 25999   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 26444   4.00  Very Good     I      I1   63.3   58.0  15984  10.01   9.94  6.31
# 26534   3.67    Premium     I      I1   62.4   56.0  16193   9.86   9.81  6.13
# 27130   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27679   3.51    Premium     J     VS2   62.5   59.0  18701   9.66   9.63  6.03

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 1.2. Create a series of the price of all of the diamonds that have carat greater than 3.5.

# %%
diamonds.loc[diamonds['carat']> 3.5, 'price']
# Out:
# 23644    11668
# 25998    15223
# 25999    15223
# 26444    15984
# 26534    16193
# 27130    17329
# 27415    18018
# 27630    18531
# 27679    18701
# Name: price, dtype: int64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 1.3. For ideal cut diamonds whose price is greater than 10000, find the number of diamonds having each clarity.

# %%
diamonds.loc[diamonds['price']> 10000].groupby(diamonds['clarity'])['carat'].count()
diamonds.loc[(diamonds['price']> 10000)&(diamonds['cut'] == 'Ideal')].groupby(diamonds['clarity'])['carat'].count()
# Out:
# clarity
# I1        8
# IF       80
# SI1     344
# SI2     318
# VS1     280
# VS2     351
# VVS1    132
# VVS2    257
# Name: carat, dtype: int64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 1.4 Write a Pandas program to create a new 'price/carat' Series (use bracket notation to define the Series name) of the diamonds DataFrame and fill series with the price per carat of all diamonds.

# %%
diamonds['price/carat'] = round(diamonds['price'] / diamonds['carat'], 2)

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# ## 2. Vancouver street trees data
#
# 2.1. Load the Vancouver street trees data provided on Blackboard. What is the most common genus of tree?

# %%
vancouver = pd.read_csv('Datasets/StreetTrees_MountPleasant.csv')
vancouver.head()
vancouver['GENUS_NAME'].value_counts()
vancouver['GENUS_NAME'].value_counts().head()
# Out:
# ACER        1621
# PRUNUS      1251
# PYRUS        387
# TILIA        299
# CARPINUS     297
# Name: GENUS_NAME, dtype: int64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 2.2. Find the mean diameter of trees with height range ID 9.

# %%
vancouver.loc[vancouver['HEIGHT_RANGE_ID'] == 9, 'DIAMETER'].mean()
# Out:
# 30.183333333333334

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 2.3. Get a Series of HEIGHT_RANGE_ID's for only the trees with a diameters greater than the average diameter of all trees, and drop any NaN values.

# %%
vancouver['HEIGHT_RANGE_ID'].where((vancouver['DIAMETER'] < vancouver['DIAMETER'].mean())).dropna()
# Out:
# 0       2.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 6169    1.0
# 6170    1.0
# 6171    1.0
# 6172    1.0
# 6174    1.0
# Name: HEIGHT_RANGE_ID, Length: 3633, dtype: float64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 2.4. Produce a pandas data frame giving the maximum and minimum height range id on each street.

# %%
#diamonds.groupby(['cut','clarity'])[['price', 'carat']].mean()
vancouver.groupby(['STD_STREET'])[['HEIGHT_RANGE_ID']].max()
vancouver.groupby(['STD_STREET'])[['HEIGHT_RANGE_ID']].min()
vancouver.groupby('STD_STREET').agg({'HEIGHT_RANGE_ID': ['min', 'max']}).head()
# Out:
#              HEIGHT_RANGE_ID
#                          min max
# STD_STREET
# ALBERTA ST                 0   8
# ATHLETES WAY               2   4
# BRUNSWICK ST               1   6
# CAMBIE ST                  1   7
# CAROLINA ST                1   6

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# ## 3. Iris flower example data
#
# 3.1. Load the iris.csv flower data. Add two extra columns to the data frame giving the ratio of sepal length over width and petal length over width.

# %%
iris = pd.read_csv('Datasets/iris.csv')
iris['Sepal.Ratio']=iris['Sepal.Length']/iris['Sepal.Width']
iris['Petal.Ratio']=iris['Petal.Length']/iris['Petal.Width']
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species  Sepal.Ratio  \
# 1           5.1          3.5           1.4          0.2  setosa     1.457143
# 2           4.9          3.0           1.4          0.2  setosa     1.633333
# 3           4.7          3.2           1.3          0.2  setosa     1.468750
# 4           4.6          3.1           1.5          0.2  setosa     1.483871
# 5           5.0          3.6           1.4          0.2  setosa     1.388889
#
#    Petal.Ratio
# 1          7.0
# 2          7.0
# 3          6.5
# 4          7.5
# 5          7.0

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 3.2. Calculate the mean of the ratio between sepal length and width for each species.

# %%
iris['Sepal.Ratio'].mean(), iris['Petal.Ratio'].mean()
# Out:
# (1.953680870534934, 4.310499757025204)

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
#
# 3.3. Perform a data discovery on the dataset.
# - How many classes are?
# - What is the distribution of the classes?
# - What are the characteristic of the data in general/per class?
# You can use methods like unique and describe.

# %%
iris.head()
iris.Species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.Species.value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: Species, dtype: int64

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Sepal.Ratio  \
# count    150.000000   150.000000    150.000000   150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333     1.953681
# std        0.828066     0.435866      1.765298     0.762238     0.400480
# min        4.300000     2.000000      1.000000     0.100000     1.268293
# 25%        5.100000     2.800000      1.600000     0.300000     1.546188
# 50%        5.800000     3.000000      4.350000     1.300000     2.032292
# 75%        6.400000     3.300000      5.100000     1.800000     2.224910
# max        7.900000     4.400000      6.900000     2.500000     2.961538
#
#        Petal.Ratio
# count   150.000000
# mean      4.310500
# std       2.489648
# min       2.125000
# 25%       2.802381
# 50%       3.300000
# 75%       4.666667
# max      15.000000

# %%
iris.loc[iris['Species'] == 'setosa'].describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Sepal.Ratio  \
# count      50.00000    50.000000     50.000000    50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000     1.470188
# std         0.35249     0.379064      0.173664     0.105386     0.118750
# min         4.30000     2.300000      1.000000     0.100000     1.268293
# 25%         4.80000     3.200000      1.400000     0.200000     1.385684
# 50%         5.00000     3.400000      1.500000     0.200000     1.463063
# 75%         5.20000     3.675000      1.575000     0.300000     1.541444
# max         5.80000     4.400000      1.900000     0.600000     1.956522
#
#        Petal.Ratio
# count    50.000000
# mean      6.908000
# std       2.854545
# min       2.666667
# 25%       4.687500
# 50%       7.000000
# 75%       7.500000
# max      15.000000

# %%
iris.loc[iris['Species'] == 'virginica'].describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Sepal.Ratio  \
# count      50.00000    50.000000     50.000000     50.00000    50.000000
# mean        6.58800     2.974000      5.552000      2.02600     2.230453
# std         0.63588     0.322497      0.551895      0.27465     0.246992
# min         4.90000     2.200000      4.500000      1.40000     1.823529
# 25%         6.22500     2.800000      5.100000      1.80000     2.031771
# 50%         6.50000     3.000000      5.550000      2.00000     2.169540
# 75%         6.90000     3.175000      5.875000      2.30000     2.342949
# max         7.90000     3.800000      6.900000      2.50000     2.961538
#
#        Petal.Ratio
# count    50.000000
# mean      2.780662
# std       0.407367
# min       2.125000
# 25%       2.511364
# 50%       2.666667
# 75%       3.055556
# max       4.000000

# %%
iris.loc[iris['Species'] == 'versicolor'].describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Sepal.Ratio  \
# count     50.000000    50.000000     50.000000    50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000     2.160402
# std        0.516171     0.313798      0.469911     0.197753     0.228658
# min        4.900000     2.000000      3.000000     1.000000     1.764706
# 25%        5.600000     2.525000      4.000000     1.200000     2.033929
# 50%        5.900000     2.800000      4.350000     1.300000     2.161290
# 75%        6.300000     3.000000      4.600000     1.500000     2.232692
# max        7.000000     3.400000      5.100000     1.800000     2.818182
#
#        Petal.Ratio
# count    50.000000
# mean      3.242837
# std       0.312456
# min       2.666667
# 25%       3.016667
# 50%       3.240385
# 75%       3.417582
# max       4.100000

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
#
# 3.4. For flowers whos petal ratio is greater than 3cm, find the mean sepal ratio for each species.
#
# You can use methods you have already used in the previoius tasks to complete this task.

# %%
iris.loc[iris['Petal.Ratio']> 3].groupby(['Species'])['Sepal.Ratio'].mean()
# Out:
# Species
# setosa        1.470188
# versicolor    2.160402
# virginica     2.230453
# Name: Sepal.Ratio, dtype: float64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# ## 4 Philadelphia bike share live data
#
# 4.1 Complete the code below to load a JSON live feed for a Philadelphia bike share program into a pandas data frame. It may help to look at the JSON data in a visual inspector. One way of doing this is to open the url given in Firefox. Once you have loaded the data, look at the head of the data frame, and list all of the columns.
#
# (I've had to add in some header data to the request, as the server rejects all requests without a user agent string)
#
# *You can use the pandas function json_normalize that was imported at the start of the notebook, but you need to pass it a suitable part of the JSON data.*
#
# *The indego_bikes_data object returned by requests.get() can be converted to a Python data structure using the json() method*
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html

# %%
indego_bikes_url = ("https://www.rideindego.com/stations/json/")
headers = {'User-Agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:63.0) Gecko/20100101 Firefox/63.0"}
indego_bikes_data = requests.get(indego_bikes_url,headers=headers)

# %%
##To display the data you can use the following line
indego_bikes_data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [-75.16374, 39.95378],
#     'type': 'Point'},
#    'properties': {'id': 3004,
#     'name': 'Municipal Services Building Plaza',
#     'coordinates': [-75.16374, 39.95378],
#     'totalDocks': 30,
#     'docksAvailable': 29,
#     'bikesAvailable': 1,
#     'classicBikesAvailable': 0,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 1,
#     'rewardDocksAvailable': 29,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1401 John F. Kennedy Blvd.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19102',
#     'bikes': [{'dockNumber': 25,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3004,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95378,
#     'longitude': -75.16374},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14403, 39.94733], 'type': 'Point'},
#    'properties': {'id': 3005,
#     'name': 'Welcome Park, NPS',
#     'coordinates': [-75.14403, 39.94733],
#     'totalDocks': 13,
#     'docksAvailable': 9,
#     'bikesAvailable': 4,
#     'classicBikesAvailable': 2,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 2,
#     'rewardBikesAvailable': 4,
#     'rewardDocksAvailable': 9,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '191 S. 2nd St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19106',
#     'bikes': [{'dockNumber': 2,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3005,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94733,
#     'longitude': -75.14403},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.20311, 39.9522], 'type': 'Point'},
#    'properties': {'id': 3006,
#     'name': '40th & Spruce',
#     'coordinates': [-75.20311, 39.9522],
#     'totalDocks': 17,
#     'docksAvailable': 6,
#     'bikesAvailable': 10,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 5,
#     'rewardBikesAvailable': 10,
#     'rewardDocksAvailable': 6,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '246 S. 40th St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 9,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3006,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.9522,
#     'longitude': -75.20311},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.15993, 39.94517], 'type': 'Point'},
#    'properties': {'id': 3007,
#     'name': '11th & Pine, Kahn Park',
#     'coordinates': [-75.15993, 39.94517],
#     'totalDocks': 20,
#     'docksAvailable': 15,
#     'bikesAvailable': 4,
#     'classicBikesAvailable': 4,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 0,
#     'rewardBikesAvailable': 4,
#     'rewardDocksAvailable': 15,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '328 S. 11th St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19107',
#     'bikes': [{'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 19,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3007,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94517,
#     'longitude': -75.15993},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.15114, 39.97944], 'type': 'Point'},
#    'properties': {'id': 3008,
#     'name': 'Temple University Station',
#     'coordinates': [-75.15114, 39.97944],
#     'totalDocks': 19,
#     'docksAvailable': 14,
#     'bikesAvailable': 5,
#     'classicBikesAvailable': 2,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 3,
#     'rewardBikesAvailable': 5,
#     'rewardDocksAvailable': 14,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1076 Berks Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19122',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 19,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3008,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.97944,
#     'longitude': -75.15114},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.18982, 39.95576], 'type': 'Point'},
#    'properties': {'id': 3009,
#     'name': '33rd & Market',
#     'coordinates': [-75.18982, 39.95576],
#     'totalDocks': 14,
#     'docksAvailable': 0,
#     'bikesAvailable': 12,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 7,
#     'rewardBikesAvailable': 12,
#     'rewardDocksAvailable': 0,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '3318 Market St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 3,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 7,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3009,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95576,
#     'longitude': -75.18982},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.16618, 39.94711], 'type': 'Point'},
#    'properties': {'id': 3010,
#     'name': '15th & Spruce',
#     'coordinates': [-75.16618, 39.94711],
#     'totalDocks': 22,
#     'docksAvailable': 11,
#     'bikesAvailable': 11,
#     'classicBikesAvailable': 6,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 5,
#     'rewardBikesAvailable': 11,
#     'rewardDocksAvailable': 11,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1483 Spruce St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19102',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 2,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3010,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94711,
#     'longitude': -75.16618},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.19649, 39.95967], 'type': 'Point'},
#    'properties': {'id': 3011,
#     'name': '38th & Powelton',
#     'coordinates': [-75.19649, 39.95967],
#     'totalDocks': 20,
#     'docksAvailable': 13,
#     'bikesAvailable': 6,
#     'classicBikesAvailable': 6,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 0,
#     'rewardBikesAvailable': 6,
#     'rewardDocksAvailable': 13,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '3788 Powelton Avenue',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3011,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95967,
#     'longitude': -75.19649},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.17747, 39.94218], 'type': 'Point'},
#    'properties': {'id': 3012,
#     'name': '21st & Catharine',
#     'coordinates': [-75.17747, 39.94218],
#     'totalDocks': 27,
#     'docksAvailable': 16,
#     'bikesAvailable': 11,
#     'classicBikesAvailable': 9,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 2,
#     'rewardBikesAvailable': 11,
#     'rewardDocksAvailable': 16,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '807 S. 21st St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19149',
#     'bikes': [{'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 18,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 20,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 22,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 23,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 25,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3012,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94218,
#     'longitude': -75.17747},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14792, 39.96317], 'type': 'Point'},
#    'properties': {'id': 3013,
#     'name': '6th & Fairmount',
#     'coordinates': [-75.14792, 39.96317],
#     'totalDocks': 17,
#     'docksAvailable': 11,
#     'bikesAvailable': 6,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 6,
#     'rewardDocksAvailable': 11,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '674 N. 6th St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19123',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 2,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3013,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.96317,
#     'longitude': -75.14792},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.17369, 39.95886], 'type': 'Point'},
#    'properties': {'id': 3014,
#     'name': '21st & Winter, Franklin Institute',
#     'coordinates': [-75.17369, 39.95886],
#     'totalDocks': 25,
#     'docksAvailable': 24,
#     'bikesAvailable': 1,
#     'classicBikesAvailable': 0,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 1,
#     'rewardDocksAvailable': 24,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '2090 Winter St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19103',
#     'bikes': [{'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3014,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95886,
#     'longitude': -75.17369},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14886, 39.94735], 'type': 'Point'},
#    'properties': {'id': 3015,
#     'name': '4th & Walnut, NPS',
#     'coordinates': [-75.14886, 39.94735],
#     'totalDocks': 11,
#     'docksAvailable': 3,
#     'bikesAvailable': 7,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 2,
#     'rewardBikesAvailable': 7,
#     'rewardDocksAvailable': 3,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '422 Walnut St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19106',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 7,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3015,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94735,
#     'longitude': -75.14886},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.1547, 39.96892], 'type': 'Point'},
#    'properties': {'id': 3016,
#     'name': '11th & Poplar, John F. Street Community Center',
#     'coordinates': [-75.1547, 39.96892],
#     'totalDocks': 15,
#     'docksAvailable': 5,
#     'bikesAvailable': 10,
#     'classicBikesAvailable': 9,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 10,
#     'rewardDocksAvailable': 5,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1100 Poplar St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19123',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3016,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.96892,
#     'longitude': -75.1547},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14371, 39.98003], 'type': 'Point'},
#    'properties': {'id': 3017,
#     'name': '6th & Berks',
#     'coordinates': [-75.14371, 39.98003],
#     'totalDocks': 15,
#     'docksAvailable': 13,
#     'bikesAvailable': 2,
#     'classicBikesAvailable': 1,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 2,
#     'rewardDocksAvailable': 13,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Unavailable',
#     'kioskConnectionStatus': 'Unresponsive',
#     'kioskType': 1,
#     'addressStreet': '527 W. Berks St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19122',
#     'bikes': [{'dockNumber': 11,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3017,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.98003,
#     'longitude': -75.14371},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.15979, 39.95273], 'type': 'Point'},
#    'properties': {'id': 3018,
#     'name': '12th & Filbert',
#     'coordinates': [-75.15979, 39.95273],
#     'totalDocks': 18,
#     'docksAvailable': 2,
#     'bikesAvailable': 13,
#     'classicBikesAvailable': 7,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 6,
#     'rewardBikesAvailable': 13,
#     'rewardDocksAvailable': 2,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1200 Filbert St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19107',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 12,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 18,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3018,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95273,
#     'longitude': -75.15979},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14983, 39.95403], 'type': 'Point'},
#    'properties': {'id': 3019,
#     'name': '6th & Race',
#     'coordinates': [-75.14983, 39.95403],
#     'totalDocks': 15,
#     'docksAvailable': 5,
#     'bikesAvailable': 9,
#     'classicBikesAvailable': 6,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 3,
#     'rewardBikesAvailable': 9,
#     'rewardDocksAvailable': 5,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '160 N. 6th St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19106',
#     'bikes': [{'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3019,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95403,
#     'longitude': -75.14983},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.19007, 39.94855], 'type': 'Point'},
#    'properties': {'id': 3020,
#     'name': 'University City Station',
#     'coordinates': [-75.19007, 39.94855],
#     'totalDocks': 36,
#     'docksAvailable': 5,
#     'bikesAvailable': 29,
#     'classicBikesAvailable': 24,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 5,
#     'rewardBikesAvailable': 29,
#     'rewardDocksAvailable': 6,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '3051 South St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19147',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 9,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 18,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 20,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 21,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 22,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 24,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 26,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 27,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 29,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 31,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 32,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 33,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 34,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 35,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 36,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3020,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94855,
#     'longitude': -75.19007},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.16902, 39.9539], 'type': 'Point'},
#    'properties': {'id': 3021,
#     'name': '18th & JFK',
#     'coordinates': [-75.16902, 39.9539],
#     'totalDocks': 34,
#     'docksAvailable': 21,
#     'bikesAvailable': 12,
#     'classicBikesAvailable': 2,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 10,
#     'rewardBikesAvailable': 12,
#     'rewardDocksAvailable': 21,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1750 John F. Kennedy Blvd.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19103',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 4,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 18,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 21,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 24,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 28,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 31,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 33,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3021,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.9539,
#     'longitude': -75.16902},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.18323, 39.95472], 'type': 'Point'},
#    'properties': {'id': 3022,
#     'name': 'Amtrak 30th Street Station',
#     'coordinates': [-75.18323, 39.95472],
#     'totalDocks': 21,
#     'docksAvailable': 8,
#     'bikesAvailable': 12,
#     'classicBikesAvailable': 9,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 3,
#     'rewardBikesAvailable': 12,
#     'rewardDocksAvailable': 9,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '2933 Market Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 18,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 19,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 20,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 21,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3022,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95472,
#     'longitude': -75.18323},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.20908, 39.94822], 'type': 'Point'},
#    'properties': {'id': 3024,
#     'name': '43rd & Chester, Clark Park',
#     'coordinates': [-75.20908, 39.94822],
#     'totalDocks': 19,
#     'docksAvailable': 15,
#     'bikesAvailable': 4,
#     'classicBikesAvailable': 1,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 3,
#     'rewardBikesAvailable': 4,
#     'rewardDocksAvailable': 15,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '598 S. 43rd St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 3,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 19,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3024,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94822,
#     'longitude': -75.20908},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.1612, 39.93724], 'type': 'Point'},
#    'properties': {'id': 3025,
#     'name': '11th & Washington',
#     'coordinates': [-75.1612, 39.93724],
#     'totalDocks': 15,
#     'docksAvailable': 5,
#     'bikesAvailable': 9,
#     'classicBikesAvailable': 4,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 5,
#     'rewardBikesAvailable': 9,
#     'rewardDocksAvailable': 5,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1084 Washington Ave.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19147',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 14,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3025,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.93724,
#     'longitude': -75.1612},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.1455, 39.94182], 'type': 'Point'},
#    'properties': {'id': 3026,
#     'name': '2nd & Lombard',
#     'coordinates': [-75.1455, 39.94182],
#     'totalDocks': 17,
#     'docksAvailable': 4,
#     'bikesAvailable': 11,
#     'classicBikesAvailable': 7,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 4,
#     'rewardBikesAvailable': 11,
#     'rewardDocksAvailable': 5,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '509 S 2nd St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19147',
#     'bikes': [{'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 3,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 11,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 16,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3026,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94182,
#     'longitude': -75.1455},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14958, 39.94061], 'type': 'Point'},
#    'properties': {'id': 3028,
#     'name': '4th & Bainbridge',
#     'coordinates': [-75.14958, 39.94061],
#     'totalDocks': 15,
#     'docksAvailable': 10,
#     'bikesAvailable': 5,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 0,
#     'rewardBikesAvailable': 5,
#     'rewardDocksAvailable': 10,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '404 Bainbridge St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19147',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3028,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94061,
#     'longitude': -75.14958},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.19479, 39.9538], 'type': 'Point'},
#    'properties': {'id': 3029,
#     'name': '36th & Sansom',
#     'coordinates': [-75.19479, 39.9538],
#     'totalDocks': 17,
#     'docksAvailable': 0,
#     'bikesAvailable': 17,
#     'classicBikesAvailable': 11,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 6,
#     'rewardBikesAvailable': 17,
#     'rewardDocksAvailable': 0,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '125 S. 36th St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 2,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 16,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 17,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3029,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.9538,
#     'longitude': -75.19479},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.15716, 39.93935], 'type': 'Point'},
#    'properties': {'id': 3030,
#     'name': 'Darien & Catharine',
#     'coordinates': [-75.15716, 39.93935],
#     'totalDocks': 29,
#     'docksAvailable': 20,
#     'bikesAvailable': 9,
#     'classicBikesAvailable': 8,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 9,
#     'rewardDocksAvailable': 20,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '840 S. Darien St.',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19147',
#     'bikes': [{'dockNumber': 1,
# ...
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 21,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 22,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3247,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.96538,
#     'longitude': -75.21514},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.18335, 39.94213], 'type': 'Point'},
#    'properties': {'id': 3248,
#     'name': '24th & Christian',
#     'coordinates': [-75.18335, 39.94213],
#     'totalDocks': 22,
#     'docksAvailable': 17,
#     'bikesAvailable': 5,
#     'classicBikesAvailable': 3,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 2,
#     'rewardBikesAvailable': 5,
#     'rewardDocksAvailable': 17,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '2418 Christian Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19146',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 2,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 19,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3248,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.94213,
#     'longitude': -75.18335},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.19079, 39.95784], 'type': 'Point'},
#    'properties': {'id': 3249,
#     'name': '34th & Arch',
#     'coordinates': [-75.19079, 39.95784],
#     'totalDocks': 22,
#     'docksAvailable': 13,
#     'bikesAvailable': 8,
#     'classicBikesAvailable': 2,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 6,
#     'rewardBikesAvailable': 8,
#     'rewardDocksAvailable': 14,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '3383 Arch Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19104',
#     'bikes': [{'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 12,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None},
#      {'dockNumber': 14,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 18,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 21,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3249,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95784,
#     'longitude': -75.19079},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.14575, 39.95673], 'type': 'Point'},
#    'properties': {'id': 3250,
#     'name': '4th & Wood',
#     'coordinates': [-75.14575, 39.95673],
#     'totalDocks': 23,
#     'docksAvailable': 16,
#     'bikesAvailable': 7,
#     'classicBikesAvailable': 7,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 0,
#     'rewardBikesAvailable': 7,
#     'rewardDocksAvailable': 16,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '390 Wood Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19106',
#     'bikes': [{'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 11,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 17,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3250,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95673,
#     'longitude': -75.14575},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.19319, 39.93366], 'type': 'Point'},
#    'properties': {'id': 3251,
#     'name': '29th & Tasker',
#     'coordinates': [-75.19319, 39.93366],
#     'totalDocks': 21,
#     'docksAvailable': 11,
#     'bikesAvailable': 10,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 5,
#     'rewardBikesAvailable': 10,
#     'rewardDocksAvailable': 11,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '2900 Tasker Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19145',
#     'bikes': [{'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 3,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 13,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3251,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.93366,
#     'longitude': -75.19319},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.19324, 39.93882], 'type': 'Point'},
#    'properties': {'id': 3252,
#     'name': '30th & Oakford',
#     'coordinates': [-75.19324, 39.93882],
#     'totalDocks': 20,
#     'docksAvailable': 14,
#     'bikesAvailable': 6,
#     'classicBikesAvailable': 2,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 4,
#     'rewardBikesAvailable': 6,
#     'rewardDocksAvailable': 14,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1206 S 30th Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19146',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 16,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 18,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3252,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.93882,
#     'longitude': -75.19324},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.18996, 39.93174], 'type': 'Point'},
#    'properties': {'id': 3253,
#     'name': '27th & Morris - Vare Recreation Center',
#     'coordinates': [-75.18996, 39.93174],
#     'totalDocks': 21,
#     'docksAvailable': 9,
#     'bikesAvailable': 12,
#     'classicBikesAvailable': 8,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 4,
#     'rewardBikesAvailable': 12,
#     'rewardDocksAvailable': 9,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '171 S 27th Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19145',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 4,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 5,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 7,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 10,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 15,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 17,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 19,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 20,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3253,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.93174,
#     'longitude': -75.18996},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.16065, 39.98091], 'type': 'Point'},
#    'properties': {'id': 3254,
#     'name': '16th & Montgomery',
#     'coordinates': [-75.16065, 39.98091],
#     'totalDocks': 18,
#     'docksAvailable': 18,
#     'bikesAvailable': 0,
#     'classicBikesAvailable': 0,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 0,
#     'rewardBikesAvailable': 0,
#     'rewardDocksAvailable': 18,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '1809 N 16th Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19121',
#     'bikes': [],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3254,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.98091,
#     'longitude': -75.16065},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.16438, 39.95095], 'type': 'Point'},
#    'properties': {'id': 3255,
#     'name': 'Broad & Chestnut',
#     'coordinates': [-75.16438, 39.95095],
#     'totalDocks': 15,
#     'docksAvailable': 9,
#     'bikesAvailable': 6,
#     'classicBikesAvailable': 5,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 6,
#     'rewardDocksAvailable': 9,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 10,
#     'addressStreet': '1405 Chestnut Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19107',
#     'bikes': [{'dockNumber': 4,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 6,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 8,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 9,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 12,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 15,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3255,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95095,
#     'longitude': -75.16438},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-75.17779, 39.95269], 'type': 'Point'},
#    'properties': {'id': 3256,
#     'name': '23rd & Chestnut',
#     'coordinates': [-75.17779, 39.95269],
#     'totalDocks': 23,
#     'docksAvailable': 17,
#     'bikesAvailable': 4,
#     'classicBikesAvailable': 3,
#     'smartBikesAvailable': 0,
#     'electricBikesAvailable': 1,
#     'rewardBikesAvailable': 4,
#     'rewardDocksAvailable': 17,
#     'kioskStatus': 'FullService',
#     'kioskPublicStatus': 'Active',
#     'kioskConnectionStatus': 'Active',
#     'kioskType': 1,
#     'addressStreet': '2223 Chestnut Street',
#     'addressCity': 'Philadelphia',
#     'addressState': 'PA',
#     'addressZipCode': '19103',
#     'bikes': [{'dockNumber': 1,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 2,
#       'isElectric': True,
#       'isAvailable': False,
#       'battery': 0.8},
#      {'dockNumber': 3,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 5,
#       'isElectric': True,
#       'isAvailable': True,
#       'battery': 0.8},
#      {'dockNumber': 14,
#       'isElectric': False,
#       'isAvailable': True,
#       'battery': None},
#      {'dockNumber': 23,
#       'isElectric': False,
#       'isAvailable': False,
#       'battery': None}],
#     'closeTime': None,
#     'eventEnd': None,
#     'eventStart': None,
#     'isEventBased': False,
#     'isVirtual': False,
#     'kioskId': 3256,
#     'notes': None,
#     'openTime': None,
#     'publicText': '',
#     'timeZone': None,
#     'trikesAvailable': 0,
#     'latitude': 39.95269,
#     'longitude': -75.17779},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
bikes = json_normalize(indego_bikes_data.json()['features'])
bikes.head()
# Out:
#       type   geometry.coordinates geometry.type  properties.id  \
# 0  Feature  [-75.16374, 39.95378]         Point           3004
# 1  Feature  [-75.14403, 39.94733]         Point           3005
# 2  Feature   [-75.20311, 39.9522]         Point           3006
# 3  Feature  [-75.15993, 39.94517]         Point           3007
# 4  Feature  [-75.15114, 39.97944]         Point           3008
#
#                      properties.name properties.coordinates  \
# 0  Municipal Services Building Plaza  [-75.16374, 39.95378]
# 1                  Welcome Park, NPS  [-75.14403, 39.94733]
# 2                      40th & Spruce   [-75.20311, 39.9522]
# 3             11th & Pine, Kahn Park  [-75.15993, 39.94517]
# 4          Temple University Station  [-75.15114, 39.97944]
#
#    properties.totalDocks  properties.docksAvailable  \
# 0                     30                         29
# 1                     13                          9
# 2                     17                          6
# 3                     20                         15
# 4                     19                         14
#
#    properties.bikesAvailable  properties.classicBikesAvailable  ...  \
# 0                          1                                 0  ...
# 1                          4                                 2  ...
# 2                         10                                 5  ...
# 3                          4                                 4  ...
# 4                          5                                 2  ...
#
#    properties.isEventBased  properties.isVirtual  properties.kioskId  \
# 0                    False                 False                3004
# 1                    False                 False                3005
# 2                    False                 False                3006
# 3                    False                 False                3007
# 4                    False                 False                3008
#
#    properties.notes properties.openTime properties.publicText  \
# 0              None                None
# 1              None                None
# 2              None                None
# 3              None                None
# 4              None                None
#
#   properties.timeZone  properties.trikesAvailable properties.latitude  \
# 0                None                           0            39.95378
# 1                None                           0            39.94733
# 2                None                           0            39.95220
# 3                None                           0            39.94517
# 4                None                           0            39.97944
#
#   properties.longitude
# 0            -75.16374
# 1            -75.14403
# 2            -75.20311
# 3            -75.15993
# 4            -75.15114
#
# [5 rows x 36 columns]

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 4.2. Is there any street with more than one bike station?

# %%
bikes.groupby("properties.addressStreet").count()['properties.bikesAvailable'].max()
# Out:
# 1

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 4.3. Use pandas to count the total number of available docks in each zip code, producing a Series of zipcodes and available dock counts.
#
# *You can use the pandas method sum() on a grouby object to add the all values in a particular group*.

# %%
bikes.groupby("properties.addressZipCode")['properties.docksAvailable'].sum()
bikes.groupby("properties.addressZipCode")[['properties.docksAvailable']].sum()
# Out:
#                            properties.docksAvailable
# properties.addressZipCode
# 19102                                             64
# 19103                                            175
# 19104                                            269
# 19106                                            129
# 19107                                             79
# 19112                                             60
# 19121                                            115
# 19122                                            170
# 19123                                             95
# 19125                                             36
# 19130                                            263
# 19131                                             29
# 19132                                             24
# 19139                                             30
# 19143                                             18
# 19145                                             37
# 19146                                            221
# 19147                                            126
# 19148                                             83
# 19149                                             16

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# __4.4*__. Using pandas, find the difference between the minimum and maximum number of available bikes at docks within each zip code.

# %%
##Option 1
bikes.groupby("properties.addressZipCode").agg({'properties.rewardDocksAvailable': ['min', 'max', np.ptp]})
bikes.groupby("properties.addressZipCode")['properties.rewardDocksAvailable'].agg(['min', 'max', np.ptp])

##Option 2
min_max_df = bikes.groupby("properties.addressZipCode")['properties.rewardDocksAvailable'].agg(['min', 'max'])
min_max_df['diff'] = min_max_df['max']-min_max_df['min']
min_max_df
# Out:
#                            min  max  diff
# properties.addressZipCode
# 19102                        1   29    28
# 19103                        0   24    24
# 19104                        0   32    32
# 19106                        1   23    22
# 19107                        1   15    14
# 19112                       12   19     7
# 19121                       12   18     6
# 19122                        5   19    14
# 19123                        5   15    10
# 19125                        6   25    19
# 19130                        7   36    29
# 19131                       15   15     0
# 19132                        9   15     6
# 19139                       11   19     8
# 19143                        9   10     1
# 19145                        8   11     3
# 19146                        7   28    21
# 19147                        5   22    17
# 19148                       10   23    13
# 19149                       16   16     0

# %% [markdown]
# __4.5*__. Write Python code using pandas to determine the postal code with the highest median of docks available.

# %%
bikes.groupby("properties.addressZipCode")['properties.rewardDocksAvailable'].agg(['median']).sort_values('median',ascending=False).head(3)
# Out:
#                            median
# properties.addressZipCode
# 19130                        16.0
# 19149                        16.0
# 19131                        15.0

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# ## 5 Bikes Dataset
#
# Load the bikes.csv file into a pandas data frame. Using the DataFrame method isnull(), you can produce a DataFrame where each value is either True if the value is  missing, or False if it is present.

# %% [markdown]
# 5.1. Produce a count of the number of missing values in each column in the DataFrame.
#
# *Tip - the sum() method treats True and False values as 1 and 0 respectively https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html*

# %%
bike = pd.read_csv('Datasets/bikes.csv')
bike.isnull().sum()
# Out:
# Rental ID                    0
# Start Time                   0
# End Time                     0
# Bike ID                      0
# Duration in Seconds          0
# Start Station ID             0
# Start Station Name           0
# End Station ID               0
# End Station Name             0
# User Type                    0
# Member Gender           185554
# Member Birthday Year    180953
# dtype: int64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 5.2. Think of a sensible way of removing the missing values and use this to create a new DataFrame with no missing values. You can use the copy() method to duplicate a DataFrame before modifying it.

# %%
bike2 = bike.dropna().copy()
bike2.isnull().sum()
# Out:
# Rental ID               0
# Start Time              0
# End Time                0
# Bike ID                 0
# Duration in Seconds     0
# Start Station ID        0
# Start Station Name      0
# End Station ID          0
# End Station Name        0
# User Type               0
# Member Gender           0
# Member Birthday Year    0
# dtype: int64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 5.3. Use the describe() method to calculate statistics of the columns in the data frame. Is there anything strange about the values in a column?

# %%
bike2.describe()
# Out:
#           Rental ID        Bike ID  Duration in Seconds  Start Station ID  \
# count  9.226080e+05  922608.000000         9.226080e+05     922608.000000
# mean   2.281821e+07    3410.908376         9.811843e+02        204.408119
# std    3.747956e+05    1912.395388         7.969447e+03        155.093432
# min    2.217853e+07       1.000000         6.100000e+01          2.000000
# 25%    2.249225e+07    1748.000000         3.880000e+02         81.000000
# 50%    2.280984e+07    3491.000000         6.460000e+02        176.000000
# 75%    2.314255e+07    5100.000000         1.097000e+03        291.000000
# max    2.347939e+07    6471.000000         4.439590e+06        664.000000
#
#        End Station ID  Member Birthday Year
# count   922608.000000         922608.000000
# mean       205.009409           1983.954518
# std        154.434312             10.788886
# min          2.000000           1759.000000
# 25%         81.000000           1979.000000
# 50%        176.000000           1987.000000
# 75%        293.000000           1992.000000
# max        664.000000           2014.000000

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 5.5. Convert the Start Time and End Time columns to pandas datetime objects. You can do this using the pd.to_datetime method on those columns.
#
# Create a new column in the data frame that gives the day of the week the journey was started on. You can extract the day of the week from a datetime object using the .dayofweek attribue, and use the apply method of a column in a DataFrame to apply a function to each value in the column.

# %%
bike2['Start Time'] = pd.to_datetime(bike2['Start Time'])
bike2['End Time'] = pd.to_datetime(bike2['End Time'])
bike2.head()
# Out:
#    Rental ID          Start Time            End Time  Bike ID  \
# 0   22178529 2019-04-01 00:02:22 2019-04-01 00:09:48     6251
# 1   22178530 2019-04-01 00:03:02 2019-04-01 00:20:30     6226
# 3   22178531 2019-04-01 00:11:07 2019-04-01 00:15:19     5649
# 4   22178532 2019-04-01 00:13:01 2019-04-01 00:18:58     4151
# 5   22178533 2019-04-01 00:19:26 2019-04-01 00:36:13     3270
#
#    Duration in Seconds  Start Station ID         Start Station Name  \
# 0                446.0                81         Daley Center Plaza
# 1               1048.0               317        Wood St & Taylor St
# 3                252.0               283  LaSalle St & Jackson Blvd
# 4                357.0                26   McClurg Ct & Illinois St
# 5               1007.0               202       Halsted St & 18th St
#
#    End Station ID           End Station Name   User Type Member Gender  \
# 0              56  Desplaines St & Kinzie St  Subscriber          Male
# 1              59  Wabash Ave & Roosevelt Rd  Subscriber        Female
# 3             174      Canal St & Madison St  Subscriber          Male
# 4             133   Kingsbury St & Kinzie St  Subscriber          Male
# 5             129  Blue Island Ave & 18th St  Subscriber          Male
#
#    Member Birthday Year   Age
# 0                1975.0  45.0
# 1                1984.0  36.0
# 3                1990.0  30.0
# 4                1993.0  27.0
# 5                1992.0  28.0

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 5.6. Create a new column in the data frame giving the (approximate) age in years of the user for each journey.

# %%
bike2['Age'] = 2020 - bike2['Member Birthday Year']
bike2.head()
# Out:
#    Rental ID          Start Time            End Time  Bike ID  \
# 0   22178529 2019-04-01 00:02:22 2019-04-01 00:09:48     6251
# 1   22178530 2019-04-01 00:03:02 2019-04-01 00:20:30     6226
# 3   22178531 2019-04-01 00:11:07 2019-04-01 00:15:19     5649
# 4   22178532 2019-04-01 00:13:01 2019-04-01 00:18:58     4151
# 5   22178533 2019-04-01 00:19:26 2019-04-01 00:36:13     3270
#
#    Duration in Seconds  Start Station ID         Start Station Name  \
# 0                446.0                81         Daley Center Plaza
# 1               1048.0               317        Wood St & Taylor St
# 3                252.0               283  LaSalle St & Jackson Blvd
# 4                357.0                26   McClurg Ct & Illinois St
# 5               1007.0               202       Halsted St & 18th St
#
#    End Station ID           End Station Name   User Type Member Gender  \
# 0              56  Desplaines St & Kinzie St  Subscriber          Male
# 1              59  Wabash Ave & Roosevelt Rd  Subscriber        Female
# 3             174      Canal St & Madison St  Subscriber          Male
# 4             133   Kingsbury St & Kinzie St  Subscriber          Male
# 5             129  Blue Island Ave & 18th St  Subscriber          Male
#
#    Member Birthday Year   Age
# 0                1975.0  45.0
# 1                1984.0  36.0
# 3                1990.0  30.0
# 4                1993.0  27.0
# 5                1992.0  28.0

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# 5.7. Investigate the numbers of journeys starting at each hour of the day. You can use the hour attribute of a pandas datetime object to extract the hour of the day from the starting times.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.hour.html

# %%
bike2['Start Hour'] = bike2['Start Time'].dt.hour
bike2.groupby(bike2['Start Hour'])['Rental ID'].count().sort_values(ascending=False)
# Out:
# Start Hour
# 17    123528
# 16     91683
# 8      81987
# 18     80356
# 7      63627
# 15     52860
# 19     52258
# 12     46294
# 13     44693
# 14     43109
# 9      41003
# 11     40290
# 10     33052
# 20     32004
# 6      28306
# 21     22527
# 22     15080
# 23      9173
# 5       8993
# 0       4829
# 1       2673
# 4       1668
# 2       1537
# 3       1078
# Name: Rental ID, dtype: int64

# %% [markdown]
# <hr style="border:2px solid black"> </hr>
#
# __5.8*__. Use the pandas cut() function to create a new column in the data frame that assigns an age range of the user for each journey. Use this new column to visualise the relationship between age group and duration of journeys.
#
# You can find documentation on the cut function here - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html

# %%
bins = [0, 2, 18, 35, 65, np.inf]
names = ['<2', '2-18', '18-35', '35-65', '65+']

bike2['AgeRange'] = pd.cut(bike2['Age'], bins, labels=names)
bike2
# Out:
#          Rental ID          Start Time            End Time  Bike ID  \
# 0         22178529 2019-04-01 00:02:22 2019-04-01 00:09:48     6251
# 1         22178530 2019-04-01 00:03:02 2019-04-01 00:20:30     6226
# 3         22178531 2019-04-01 00:11:07 2019-04-01 00:15:19     5649
# 4         22178532 2019-04-01 00:13:01 2019-04-01 00:18:58     4151
# 5         22178533 2019-04-01 00:19:26 2019-04-01 00:36:13     3270
# 6         22178534 2019-04-01 00:19:39 2019-04-01 00:23:56     3123
# 7         22178535 2019-04-01 00:26:33 2019-04-01 00:35:41     6418
# 8         22178536 2019-04-01 00:29:48 2019-04-01 00:36:11     4513
# 10        22178539 2019-04-01 00:36:20 2019-04-01 00:41:17     4666
# 11        22178540 2019-04-01 00:58:38 2019-04-01 01:04:43     3735
# 12        22178541 2019-04-01 01:09:41 2019-04-01 01:12:26     6108
# 13        22178542 2019-04-01 01:13:15 2019-04-01 01:20:38     6157
# 14        22178543 2019-04-01 01:18:09 2019-04-01 01:23:02     4384
# 15        22178544 2019-04-01 01:28:21 2019-04-01 01:31:45     4022
# 16        22178545 2019-04-01 01:31:35 2019-04-01 01:35:28     2748
# 17        22178546 2019-04-01 01:53:56 2019-04-01 02:03:02     5351
# 19        22178548 2019-04-01 02:12:53 2019-04-01 02:16:56     3325
# 20        22178549 2019-04-01 02:27:02 2019-04-01 02:30:10       93
# 21        22178550 2019-04-01 02:37:48 2019-04-01 02:41:35     3325
# 22        22178551 2019-04-01 02:42:51 2019-04-01 02:48:26     3193
# 23        22178552 2019-04-01 02:58:12 2019-04-01 03:09:14     1167
# 24        22178554 2019-04-01 02:59:22 2019-04-01 03:09:14     6418
# 25        22178555 2019-04-01 03:01:13 2019-04-01 03:04:39     1627
# 26        22178556 2019-04-01 03:15:06 2019-04-01 03:20:10     6065
# 27        22178557 2019-04-01 03:46:31 2019-04-01 03:51:23     5578
# 28        22178558 2019-04-01 03:46:46 2019-04-01 04:17:05     1065
# 29        22178559 2019-04-01 04:01:10 2019-04-01 04:12:50      268
# 30        22178560 2019-04-01 04:07:03 2019-04-01 04:13:59     6223
# 31        22178561 2019-04-01 04:11:03 2019-04-01 04:19:51     3737
# 32        22178562 2019-04-01 04:11:47 2019-04-01 04:14:15        9
# ...            ...                 ...                 ...      ...
# 1108123   23479339 2019-06-30 23:43:06 2019-07-01 00:00:55      787
# 1108124   23479340 2019-06-30 23:43:14 2019-06-30 23:49:51     4537
# 1108127   23479343 2019-06-30 23:43:38 2019-06-30 23:52:32     1484
# 1108129   23479345 2019-06-30 23:44:10 2019-07-01 01:31:41      484
# 1108130   23479346 2019-06-30 23:44:21 2019-06-30 23:49:52     2215
# 1108135   23479351 2019-06-30 23:45:10 2019-06-30 23:54:15     5047
# 1108136   23479353 2019-06-30 23:46:05 2019-07-01 00:17:16      240
# 1108137   23479354 2019-06-30 23:46:16 2019-07-01 00:17:16     5166
# 1108138   23479355 2019-06-30 23:46:19 2019-06-30 23:55:05     2092
# 1108139   23479357 2019-06-30 23:47:26 2019-07-01 00:17:15     1132
# 1108140   23479358 2019-06-30 23:48:34 2019-07-01 00:01:29     3131
# 1108141   23479360 2019-06-30 23:49:18 2019-06-30 23:55:18     3597
# 1108142   23479361 2019-06-30 23:49:29 2019-07-01 00:00:57     2099
# 1108143   23479362 2019-06-30 23:49:46 2019-07-01 00:31:52     6399
# 1108144   23479364 2019-06-30 23:49:59 2019-07-01 00:04:58     1923
# 1108145   23479365 2019-06-30 23:49:59 2019-06-30 23:55:47     2962
# 1108146   23479366 2019-06-30 23:50:02 2019-07-01 00:06:32     3410
# 1108147   23479368 2019-06-30 23:51:02 2019-07-01 00:02:46      143
# 1108148   23479371 2019-06-30 23:52:34 2019-07-01 00:05:48     5156
# 1108149   23479373 2019-06-30 23:53:59 2019-07-01 00:53:58      648
# 1108150   23479374 2019-06-30 23:54:04 2019-07-01 00:54:05     4883
# 1108152   23479377 2019-06-30 23:55:24 2019-07-01 00:04:58     1759
# 1108153   23479378 2019-06-30 23:55:58 2019-07-01 00:13:59      429
# 1108154   23479379 2019-06-30 23:56:00 2019-06-30 23:58:49     4889
# 1108155   23479380 2019-06-30 23:57:00 2019-07-01 00:04:02      993
# 1108156   23479381 2019-06-30 23:57:54 2019-07-01 00:10:47     1044
# 1108159   23479384 2019-06-30 23:58:04 2019-07-01 00:14:17     6301
# 1108160   23479385 2019-06-30 23:58:20 2019-07-01 00:25:51     4472
# 1108161   23479386 2019-06-30 23:58:52 2019-07-01 00:11:24     5021
# 1108162   23479387 2019-06-30 23:59:05 2019-07-01 00:26:14     4749
#
#          Duration in Seconds  Start Station ID  \
# 0                      446.0                81
# 1                     1048.0               317
# 3                      252.0               283
# 4                      357.0                26
# 5                     1007.0               202
# 6                      257.0               420
# 7                      548.0               503
# 8                      383.0               260
# 10                     297.0               304
# 11                     365.0                37
# 12                     165.0                75
# 13                     443.0               334
# 14                     293.0                39
# 15                     204.0               287
# 16                     233.0               148
# 17                     546.0                59
# 19                     243.0               430
# 20                     188.0               257
# 21                     227.0               427
# 22                     335.0               172
# 23                     662.0               304
# 24                     592.0               500
# 25                     206.0                90
# 26                     304.0               299
# 27                     292.0                15
# 28                    1819.0                19
# 29                     700.0               260
# 30                     416.0               156
# 31                     528.0                91
# 32                     148.0                49
# ...                      ...               ...
# 1108123               1069.0                77
# 1108124                397.0                77
# 1108127                534.0               174
# 1108129               6451.0                52
# 1108130                331.0                74
# 1108135                545.0               300
# 1108136               1871.0                59
# 1108137               1860.0                59
# 1108138                526.0               299
# 1108139               1789.0                59
# 1108140                775.0                29
# 1108141                360.0               212
# 1108142                688.0               310
# 1108143               2526.0               392
# 1108144                899.0               228
# 1108145                348.0                50
# 1108146                990.0               260
# 1108147                704.0                36
# 1108148                794.0               114
# 1108149               3599.0               268
# 1108150               3601.0               268
# 1108152                574.0                81
# 1108153               1081.0               283
# 1108154                169.0               225
# 1108155                422.0               106
# 1108156                773.0               215
# 1108159                973.0               199
# 1108160               1651.0               319
# 1108161                752.0               226
# 1108162               1629.0                85
#
#                       Start Station Name  End Station ID  \
# 0                     Daley Center Plaza              56
# 1                    Wood St & Taylor St              59
# 3              LaSalle St & Jackson Blvd             174
# 4               McClurg Ct & Illinois St             133
# 5                   Halsted St & 18th St             129
# 6                    Ellis Ave & 55th St             426
# 7              Drake Ave & Fullerton Ave             500
# 8             Kedzie Ave & Milwaukee Ave             499
# 10               Broadway & Waveland Ave             232
# 11                Dearborn St & Adams St             337
# 12               Canal St & Jackson Blvd              36
# 13           Lake Shore Dr & Belmont Ave             256
# 14                 Wabash Ave & Adams St             255
# 15               Franklin St & Monroe St              89
# 16                    State St & 33rd St             272
# 17             Wabash Ave & Roosevelt Rd              36
# 19                   MLK Jr Dr & 63rd St             427
# 20            Lincoln Ave & Waveland Ave             230
# 21           Cottage Grove Ave & 63rd St             430
# 22                    Rush St & Cedar St             635
# 23               Broadway & Waveland Ave             246
# 24       Central Park Ave & Elbridge Ave             503
# 25                       Millennium Park              44
# 26                Halsted St & Roscoe St             334
# 27                  Racine Ave & 18th St             205
# 28             Loomis St & Taylor St (*)              31
# 29            Kedzie Ave & Milwaukee Ave             485
# 30             Clark St & Wellington Ave             229
# 31          Clinton St & Washington Blvd             241
# 32               Dearborn St & Monroe St             283
# ...                                  ...             ...
# 1108123          Clinton St & Madison St             273
# 1108124          Clinton St & Madison St             621
# 1108127            Canal St & Madison St             111
# 1108129           Michigan Ave & Lake St             194
# 1108130           Kingsbury St & Erie St             212
# 1108135             Broadway & Barry Ave             144
# 1108136        Wabash Ave & Roosevelt Rd               6
# 1108137        Wabash Ave & Roosevelt Rd               6
# 1108138           Halsted St & Roscoe St             254
# 1108139        Wabash Ave & Roosevelt Rd               6
# 1108140         Noble St & Milwaukee Ave             123
# 1108141            Wells St & Hubbard St              98
# 1108142        Damen Ave & Charleston St             210
# 1108143              Perry Ave & 69th St             392
# 1108144          Damen Ave & Melrose Ave             223
# 1108145        Clark St & Ida B Wells Dr             321
# 1108146       Kedzie Ave & Milwaukee Ave             128
# 1108147       Franklin St & Jackson Blvd             199
# 1108148     Sheffield Ave & Waveland Ave             324
# 1108149       Lake Shore Dr & North Blvd             220
# 1108150       Lake Shore Dr & North Blvd             220
# 1108152               Daley Center Plaza              56
# 1108153        LaSalle St & Jackson Blvd             273
# 1108154         Halsted St & Dickens Ave             224
# 1108155            State St & Pearson St             620
# 1108156           Damen Ave & Madison St              69
# 1108159           Wabash Ave & Grand Ave             338
# 1108160    Greenview Ave & Diversey Pkwy             337
# 1108161         Racine Ave & Belmont Ave             300
# 1108162            Michigan Ave & Oak St             249
#
#                              End Station Name   User Type Member Gender  \
# 0                   Desplaines St & Kinzie St  Subscriber          Male
# 1                   Wabash Ave & Roosevelt Rd  Subscriber        Female
# 3                       Canal St & Madison St  Subscriber          Male
# 4                    Kingsbury St & Kinzie St  Subscriber          Male
# 5                   Blue Island Ave & 18th St  Subscriber          Male
# 6                         Ellis Ave & 60th St  Subscriber          Male
# 7             Central Park Ave & Elbridge Ave  Subscriber          Male
# 8                             Kosciuszko Park  Subscriber          Male
# 10              Pine Grove Ave & Waveland Ave  Subscriber          Male
# 11                     Clark St & Chicago Ave  Subscriber          Male
# 12                 Franklin St & Jackson Blvd  Subscriber          Male
# 13                     Broadway & Sheridan Rd  Subscriber          Male
# 14                 Indiana Ave & Roosevelt Rd  Subscriber          Male
# 15       Financial Pl & Ida B Wells Dr (Temp)  Subscriber          Male
# 16                      Indiana Ave & 31st St  Subscriber        Female
# 17                 Franklin St & Jackson Blvd  Subscriber          Male
# 19                Cottage Grove Ave & 63rd St  Subscriber          Male
# 20                    Lincoln Ave & Roscoe St  Subscriber          Male
# 21                        MLK Jr Dr & 63rd St  Subscriber          Male
# 22             Fairbanks St & Superior St (*)  Subscriber          Male
# 23             Ashland Ave & Belle Plaine Ave  Subscriber        Female
# 24                  Drake Ave & Fullerton Ave  Subscriber          Male
# 25                     State St & Randolph St  Subscriber        Female
# 26                Lake Shore Dr & Belmont Ave  Subscriber          Male
# 27                       Paulina St & 18th St  Subscriber          Male
# 28                  Franklin St & Chicago Ave  Subscriber          Male
# 29                Sawyer Ave & Irving Park Rd    Customer          Male
# 30                  Southport Ave & Roscoe St  Subscriber          Male
# 31                        Morgan St & Polk St  Subscriber          Male
# 32                  LaSalle St & Jackson Blvd  Subscriber          Male
# ...                                       ...         ...           ...
# 1108123                Michigan Ave & 18th St  Subscriber        Female
# 1108124             Aberdeen St & Randolph St  Subscriber          Male
# 1108127                Sedgwick St & Huron St  Subscriber        Female
# 1108129                Wabash Ave & Wacker Pl    Customer          Male
# 1108130                 Wells St & Hubbard St  Subscriber          Male
# 1108135             Larrabee St & Webster Ave  Subscriber          Male
# 1108136                        Dusable Harbor    Customer        Female
# 1108137                        Dusable Harbor    Customer        Female
# 1108138       Pine Grove Ave & Irving Park Rd  Subscriber          Male
# 1108139                        Dusable Harbor    Customer        Female
# 1108140        California Ave & Milwaukee Ave  Subscriber          Male
# 1108141            LaSalle St & Washington St    Customer          Male
# 1108142             Ashland Ave & Division St  Subscriber          Male
# 1108143                   Perry Ave & 69th St  Subscriber          Male
# 1108144            Clifton Ave & Armitage Ave  Subscriber          Male
# 1108145                   Wabash Ave & 9th St  Subscriber        Female
# 1108146               Damen Ave & Chicago Ave  Subscriber          Male
# 1108147                Wabash Ave & Grand Ave  Subscriber          Male
# 1108148          Stockton Dr & Wrightwood Ave  Subscriber        Female
# 1108149                Clark St & Drummond Pl  Subscriber          Male
# 1108150                Clark St & Drummond Pl  Subscriber        Female
# 1108152             Desplaines St & Kinzie St  Subscriber          Male
# 1108153                Michigan Ave & 18th St  Subscriber          Male
# 1108154                Halsted St & Willow St  Subscriber          Male
# 1108155  Orleans St & Chestnut St (NEXT Apts)  Subscriber          Male
# 1108156                Damen Ave & Pierce Ave  Subscriber          Male
# 1108159                 Calumet Ave & 18th St  Subscriber          Male
# 1108160                Clark St & Chicago Ave  Subscriber        Female
# 1108161                  Broadway & Barry Ave  Subscriber          Male
# 1108162                       Montrose Harbor  Subscriber          Male
#
#          Member Birthday Year   Age  Start Hour AgeRange
# 0                      1975.0  45.0           0    35-65
# 1                      1984.0  36.0           0    35-65
# 3                      1990.0  30.0           0    18-35
# 4                      1993.0  27.0           0    18-35
# 5                      1992.0  28.0           0    18-35
# 6                      1999.0  21.0           0    18-35
# 7                      1969.0  51.0           0    35-65
# 8                      1991.0  29.0           0    18-35
# 10                     1975.0  45.0           0    35-65
# 11                     1991.0  29.0           0    18-35
# 12                     1990.0  30.0           1    18-35
# 13                     1989.0  31.0           1    18-35
# 14                     1969.0  51.0           1    35-65
# 15                     1994.0  26.0           1    18-35
# 16                     1989.0  31.0           1    18-35
# 17                     1958.0  62.0           1    35-65
# 19                     1985.0  35.0           2    18-35
# 20                     1981.0  39.0           2    35-65
# 21                     1985.0  35.0           2    18-35
# 22                     1992.0  28.0           2    18-35
# 23                     1959.0  61.0           2    35-65
# 24                     1969.0  51.0           2    35-65
# 25                     1992.0  28.0           3    18-35
# 26                     1989.0  31.0           3    18-35
# 27                     1981.0  39.0           3    35-65
# 28                     1997.0  23.0           3    18-35
# 29                     1975.0  45.0           4    35-65
# 30                     1986.0  34.0           4    18-35
# 31                     1987.0  33.0           4    18-35
# 32                     1957.0  63.0           4    35-65
# ...                       ...   ...         ...      ...
# 1108123                1988.0  32.0          23    18-35
# 1108124                1989.0  31.0          23    18-35
# 1108127                1986.0  34.0          23    18-35
# 1108129                1995.0  25.0          23    18-35
# 1108130                1977.0  43.0          23    35-65
# 1108135                1980.0  40.0          23    35-65
# 1108136                1997.0  23.0          23    18-35
# 1108137                1997.0  23.0          23    18-35
# 1108138                1981.0  39.0          23    35-65
# 1108139                1998.0  22.0          23    18-35
# 1108140                1987.0  33.0          23    18-35
# 1108141                1989.0  31.0          23    18-35
# 1108142                1978.0  42.0          23    35-65
# 1108143                1957.0  63.0          23    35-65
# 1108144                1989.0  31.0          23    18-35
# 1108145                1986.0  34.0          23    18-35
# 1108146                1996.0  24.0          23    18-35
# 1108147                1992.0  28.0          23    18-35
# 1108148                1990.0  30.0          23    18-35
# 1108149                1987.0  33.0          23    18-35
# 1108150                1986.0  34.0          23    18-35
# 1108152                1975.0  45.0          23    35-65
# 1108153                1984.0  36.0          23    35-65
# 1108154                1987.0  33.0          23    18-35
# 1108155                1964.0  56.0          23    35-65
# 1108156                1962.0  58.0          23    35-65
# 1108159                1980.0  40.0          23    35-65
# 1108160                1991.0  29.0          23    18-35
# 1108161                1992.0  28.0          23    18-35
# 1108162                1987.0  33.0          23    18-35
#
# [922608 rows x 15 columns]
